# %%
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt

# %%
runs = sorted(glob("drop_train_results/run_*.csv"))
run_names = [x.split("/")[-1].split(".")[0] for x in runs]
run_names
# Out:
# ['run_1',
#  'run_10',
#  'run_2',
#  'run_3',
#  'run_4',
#  'run_5',
#  'run_6',
#  'run_7',
#  'run_8',
#  'run_9']

# %%
def plot_run(name: str):
    data = pd.read_csv(f"drop_train_results/{name}.csv", index_col="epoch")
    plt.plot(data["val_loss"], label=name)

# %%
plt.figure(figsize=(16, 9))
for run in run_names:
    plot_run(run)
plt.legend()
plt.show()
